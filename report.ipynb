# %% [markdown]
# # Title

# %% [markdown]
# Question:
#
# - Can the player's own Experience, Played Hours, Gender and Age predict whether the player will subscribe to the game newsletter?
#
# Timeline:
# - Monday: Lokkit
# - Tuesday: Yanny
# - Wednesday: Tiger
# - Thursday: Alex
#
# We are using the `players.csv` dataset in order to do these predictions

# %%
library(tidyverse)
players <- read_csv("https://raw.githubusercontent.com/Alexjhz07/DSCI-100-Project-Individual/refs/heads/main/players.csv")
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # Introduction

# %%
cc <- summary(players)
cc
players <- filter(players, played_hours != 0.0)
cc <- summary(players)
cc
# Out:
#   experience        subscribe       hashedEmail         played_hours
#  Length:196         Mode :logical   Length:196         Min.   :  0.000
#  Class :character   FALSE:52        Class :character   1st Qu.:  0.000
#  Mode  :character   TRUE :144       Mode  :character   Median :  0.100
#                                                        Mean   :  5.846
#                                                        3rd Qu.:  0.600
#                                                        Max.   :223.100
#
#      name              gender               Age
#  Length:196         Length:196         Min.   : 9.00
#  Class :character   Class :character   1st Qu.:17.00
#  Mode  :character   Mode  :character   Median :19.00
#                                        Mean   :21.14
#                                        3rd Qu.:22.75
#                                        Max.   :58.00
#                                        NA's   :2
#   experience        subscribe       hashedEmail         played_hours
#  Length:111         Mode :logical   Length:111         Min.   :  0.10
#  Class :character   FALSE:25        Class :character   1st Qu.:  0.10
#  Mode  :character   TRUE :86        Mode  :character   Median :  0.50
#                                                        Mean   : 10.32
#                                                        3rd Qu.:  1.75
#                                                        Max.   :223.10
#
#      name              gender               Age
#  Length:111         Length:111         Min.   : 9.0
#  Class :character   Class :character   1st Qu.:17.0
#  Mode  :character   Mode  :character   Median :20.0
#                                        Mean   :21.3
#                                        3rd Qu.:23.0
#                                        Max.   :58.0
#                                        NA's   :2

# %% [markdown]
# # Methods & Results:

# %% [markdown]
# We will use Logistic Regression to model the outcome prediction of ...

# %% [markdown]
# # Discussion

# %% [markdown]
# # References
